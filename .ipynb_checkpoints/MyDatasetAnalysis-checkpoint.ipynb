# %% [markdown]
# # 1. Загрузка данных, описание поставленной задачи и её первичный анализ

# %%
import numpy as np              # Одномерные и многомерные массивы (array)
import pandas as pd             # Таблицы и временные ряды (dataframe, series)
import matplotlib.pyplot as plt # Научная графика
import seaborn as sns           # Ещё больше красивой графики для визуализации данных
import sklearn                  # Алгоритмы машинного обучения

# %%
from ucimlrepo import fetch_ucirepo
predict_students_dropout_and_academic_success = fetch_ucirepo(id=697)

X = predict_students_dropout_and_academic_success.data.features.copy()
del X['Debtor']
del X['Tuition fees up to date']
del X['Curricular units 1st sem (credited)']
del X['Curricular units 1st sem (enrolled)']
del X['Curricular units 1st sem (evaluations)']
del X['Curricular units 1st sem (approved)']
del X['Curricular units 1st sem (without evaluations)']
del X['Curricular units 2nd sem (credited)']
del X['Curricular units 2nd sem (enrolled)']
del X['Curricular units 2nd sem (evaluations)']
del X['Curricular units 2nd sem (approved)']
del X['Curricular units 2nd sem (without evaluations)']
y = predict_students_dropout_and_academic_success.data.targets.copy()

X = X.join(y)

# %%
X.shape # Размерность датасета (4424 строки и 24 столбца-признака; признак, который угадываем не учитывается)
# Out:
# (4424, 25)

# %%
pd.options.display.max_columns = 25
X # Наши исходные ("сырые") данные
# Out:
#       Marital Status  Application mode  Application order  Course  \
# 0                  1                17                  5     171
# 1                  1                15                  1    9254
# 2                  1                 1                  5    9070
# 3                  1                17                  2    9773
# 4                  2                39                  1    8014
# ...              ...               ...                ...     ...
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance  Previous qualification  \
# 0                              1                       1
# 1                              1                       1
# 2                              1                       1
# 3                              1                       1
# 4                              0                       1
# ...                          ...                     ...
# 4419                           1                       1
# 4420                           1                       1
# 4421                           1                       1
# 4422                           1                       1
# 4423                           1                       1
#
#       Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                              122.0            1                      19
# 1                              160.0            1                       1
# 2                              122.0            1                      37
# 3                              122.0            1                      38
# 4                              100.0            1                      37
# ...                              ...          ...                     ...
# 4419                           125.0            1                       1
# 4420                           120.0          105                       1
# 4421                           154.0            1                      37
# 4422                           180.0            1                      37
# 4423                           152.0           22                      38
#
#       Father's qualification  Mother's occupation  Father's occupation  \
# 0                         12                    5                    9
# 1                          3                    3                    3
# 2                         37                    9                    9
# 3                         37                    5                    3
# 4                         38                    9                    9
# ...                      ...                  ...                  ...
# 4419                       1                    5                    4
# 4420                       1                    9                    9
# 4421                      37                    9                    9
# 4422                      37                    7                    4
# 4423                      37                    5                    9
#
#       Admission grade  Displaced  Educational special needs  Gender  \
# 0               127.3          1                          0       1
# 1               142.5          1                          0       1
# 2               124.8          1                          0       1
# 3               119.6          1                          0       0
# 4               141.5          0                          0       0
# ...               ...        ...                        ...     ...
# 4419            122.2          0                          0       1
# 4420            119.0          1                          0       0
# 4421            149.5          1                          0       0
# 4422            153.8          1                          0       0
# 4423            152.0          1                          0       0
#
#       Scholarship holder  Age at enrollment  International  \
# 0                      0                 20              0
# 1                      0                 19              0
# 2                      0                 19              0
# 3                      0                 20              0
# 4                      0                 45              0
# ...                  ...                ...            ...
# 4419                   0                 19              0
# 4420                   0                 18              1
# 4421                   1                 30              0
# 4422                   1                 20              0
# 4423                   0                 22              1
#
#       Curricular units 1st sem (grade)  Curricular units 2nd sem (grade)  \
# 0                             0.000000                          0.000000
# 1                            14.000000                         13.666667
# 2                             0.000000                          0.000000
# 3                            13.428571                         12.400000
# 4                            12.333333                         13.000000
# ...                                ...                               ...
# 4419                         13.600000                         12.666667
# 4420                         12.000000                         11.000000
# 4421                         14.912500                         13.500000
# 4422                         13.800000                         12.000000
# 4423                         11.666667                         13.000000
#
#       Unemployment rate  Inflation rate   GDP    Target
# 0                  10.8             1.4  1.74   Dropout
# 1                  13.9            -0.3  0.79  Graduate
# 2                  10.8             1.4  1.74   Dropout
# 3                   9.4            -0.8 -3.12  Graduate
# 4                  13.9            -0.3  0.79  Graduate
# ...                 ...             ...   ...       ...
# 4419               15.5             2.8 -4.06  Graduate
# 4420               11.1             0.6  2.02   Dropout
# 4421               13.9            -0.3  0.79   Dropout
# 4422                9.4            -0.8 -3.12  Graduate
# 4423               12.7             3.7 -1.70  Graduate
#
# [4424 rows x 25 columns]

# %% [markdown]
# ## Постановка задачи
# Данная задача является задачей классификации студентов с 3-мя классами:
# - **Graduate** (стал выпускником)
# - **Enrolled** (только что поступил)
# - **Dropout** (был отчислен за неуспеваемость).
#
# ## Описание признаков, используемых в задаче:
# - **Marital Status** – семейное положение
# - **Application mode** – "категория при зачислении" (обычный студент, иностранный студент и другое)
# - **Application order** – какой приоритет данный университет имел для студента при поступлении (от 0 до 9, 0 – студент хотел поступить именно сюда в первую очередь, 9 – студент хотел поступить сюда в последнюю очередь)
# - **Course** – специальность (33 – Технологии производства биотоплива 171 – Анимация и мультимедийный дизайн, ...)
# - **Daytime/evening attendance** – форма обучения (1 – дневная, 0 – вечерняя)
# - **Previous qualification** – предыдущее образование (ступень)
# - **Grade of previous qualification** (от 0 до 200) – оценка, полученная за предыдущее образование
# - **Nacionality** – национальность
# - **Mother's qualification** – уровень образования матери
# - **Father's qualification** – уровень образования отца
# - **Mother's occupation** – область занятости матери (вид работы)
# - **Father's occupation** – область занятости отца (вид работы)
# - **Admission grade** – общий балл при поступлении (от 0 до 200)
# - **Displaced** – переселенец (1) или нет (0)
# - **Educational special needs** – имеет особые образовательные потребности (1 – да, 0 – нет)
# - **Gender** – пол (1 – мужской, 0 – женский)
# - **Scholarship holder** – является стипендиатом (1 – да, 0 – нет)
# - **Age at enrollment** – возраст на момент зачисления в университет
# - **International** – международный (1) или нет (0) студент
# - **Curricular units 1st sem (grade)** – средний балл за 1-й семестр обучения (от 0 до 20)
# - **Curricular units 2nd sem (grade)** – средний балл за 2-й семестр обучения (от 0 до 20)
# - **Unemployment rate** – уровень безработицы в стране обучения (в %)
# - **Inflation rate** – уровень инфляции в стране обучения (в %)
# - **GDP** – ВВП страны обучения.
#
# Мы будем работать с пересчисленными выше 24 признаками.
# Некоторые побочные признаки были отсечены в самом начале работы ввиду сложнопереводимости их смысла.
#
# В нашем датасете все признаки представлены числовыми значениями, но это вовсе не означает, что все они – числовые.
# Многие из них – *числовые (дискретные)*, например, возраст на момент поступления.
# Некоторые – *числовые (непрерывные)*, например, средний балл студента.
# Также среди признаков довольно много *категориальных (неупорядоченных, т.е. номинальных)* и *бинарных*.
# Бинарные в данном случае будем считать *категориальными неупорядоченными (номинальными)*.

# %%
# Настройка типов признаков в Pandas dataframe
X['Marital Status'] = X['Marital Status'].astype('category')
X['Application mode'] = X['Application mode'].astype('category')
X['Course'] = X['Course'].astype('category')
X['Daytime/evening attendance'] = X['Daytime/evening attendance'].astype('category')
X['Previous qualification'] = X['Previous qualification'].astype('category')
X['Nacionality'] = X['Nacionality'].astype('category')
X['Mother\'s qualification'] = X['Mother\'s qualification'].astype('category')
X['Father\'s qualification'] = X['Father\'s qualification'].astype('category')
X['Mother\'s occupation'] = X['Mother\'s occupation'].astype('category')
X['Father\'s occupation'] = X['Father\'s occupation'].astype('category')
#X['Displaced'] = X['Displaced'].astype('bool')
#X['Educational special needs'] = X['Educational special needs'].astype('bool')
X['Gender'] = X['Gender'].astype('category')
#X['Scholarship holder'] = X['Scholarship holder'].astype('bool')
#X['International'] = X['International'].astype('bool')
X['Target'] = X['Target'].astype('category')
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 25 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Marital Status                    4424 non-null   category
#  1   Application mode                  4424 non-null   category
#  2   Application order                 4424 non-null   int64
#  3   Course                            4424 non-null   category
#  4   Daytime/evening attendance        4424 non-null   category
#  5   Previous qualification            4424 non-null   category
#  6   Previous qualification (grade)    4424 non-null   float64
#  7   Nacionality                       4424 non-null   category
#  8   Mother's qualification            4424 non-null   category
#  9   Father's qualification            4424 non-null   category
#  10  Mother's occupation               4424 non-null   category
#  11  Father's occupation               4424 non-null   category
#  12  Admission grade                   4424 non-null   float64
#  13  Displaced                         4424 non-null   int64
#  14  Educational special needs         4424 non-null   int64
#  15  Gender                            4424 non-null   category
#  16  Scholarship holder                4424 non-null   int64
#  17  Age at enrollment                 4424 non-null   int64
#  18  International                     4424 non-null   int64
#  19  Curricular units 1st sem (grade)  4424 non-null   float64
#  20  Curricular units 2nd sem (grade)  4424 non-null   float64
#  21  Unemployment rate                 4424 non-null   float64
#  22  Inflation rate                    4424 non-null   float64
#  23  GDP                               4424 non-null   float64
#  24  Target                            4424 non-null   category
# dtypes: category(12), float64(7), int64(6)
# memory usage: 509.9 KB

# %% [markdown]
# #### Информация о числовых признаках в нашей задаче:

# %%
X.describe(include=['int64', 'float64'])
# Out:
#        Application order  Previous qualification (grade)  Admission grade  \
# count        4424.000000                     4424.000000      4424.000000
# mean            1.727848                      132.613314       126.978119
# std             1.313793                       13.188332        14.482001
# min             0.000000                       95.000000        95.000000
# 25%             1.000000                      125.000000       117.900000
# 50%             1.000000                      133.100000       126.100000
# 75%             2.000000                      140.000000       134.800000
# max             9.000000                      190.000000       190.000000
#
#          Displaced  Educational special needs  Scholarship holder  \
# count  4424.000000                4424.000000         4424.000000
# mean      0.548373                   0.011528            0.248418
# std       0.497711                   0.106760            0.432144
# min       0.000000                   0.000000            0.000000
# 25%       0.000000                   0.000000            0.000000
# 50%       1.000000                   0.000000            0.000000
# 75%       1.000000                   0.000000            0.000000
# max       1.000000                   1.000000            1.000000
#
#        Age at enrollment  International  Curricular units 1st sem (grade)  \
# count        4424.000000    4424.000000                       4424.000000
# mean           23.265145       0.024864                         10.640822
# std             7.587816       0.155729                          4.843663
# min            17.000000       0.000000                          0.000000
# 25%            19.000000       0.000000                         11.000000
# 50%            20.000000       0.000000                         12.285714
# 75%            25.000000       0.000000                         13.400000
# max            70.000000       1.000000                         18.875000
#
#        Curricular units 2nd sem (grade)  Unemployment rate  Inflation rate  \
# count                       4424.000000        4424.000000     4424.000000
# mean                          10.230206          11.566139        1.228029
# std                            5.210808           2.663850        1.382711
# min                            0.000000           7.600000       -0.800000
# 25%                           10.750000           9.400000        0.300000
# 50%                           12.200000          11.100000        1.400000
# 75%                           13.333333          13.900000        2.600000
# max                           18.571429          16.200000        3.700000
#
#                GDP
# count  4424.000000
# mean      0.001969
# std       2.269935
# min      -4.060000
# 25%      -1.700000
# 50%       0.320000
# 75%       1.790000
# max       3.510000

# %% [markdown]
# Здесь
# - *min* – минимальное значение признака в таблице
# - *max* – максимальное значение
# - *mean* – среднее значение
# - *std* – среднеквадратическое отклонение (степень отклонения значений от среднего)
# - *25%* – 0.25-квантиль (25-й перцентиль) – значение, ниже которого лежит 25% значений
# - *50%* – медиана – значение, 50% значений меньше которого, а другие 50% больше
# - *75%* – 0.75-квантиль (75-й перцентиль) – значение, ниже которого лежит около 75%, т.е. 75% значений меньше данного.
#
# Построим матрицу корелляции числовых признаков:

# %%
corrMatrix = X.select_dtypes(include=['int64', 'float64']).corr()
corrMatrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_6a990_row0_col0, #T_6a990_row1_col1, #T_6a990_row2_col2, #T_6a990_row3_col3, #T_6a990_row4_col4, #T_6a990_row5_col5, #T_6a990_row6_col6, #T_6a990_row7_col7, #T_6a990_row8_col8, #T_6a990_row9_col9, #T_6a990_row10_col10, #T_6a990_row11_col11, #T_6a990_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6a990_row0_col1, #T_6a990_row3_col4, #T_6a990_row11_col4 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_6a990_row0_col2, #T_6a990_row0_col7, #T_6a990_row3_col6, #T_6a990_row5_col7, #T_6a990_row6_col0, #T_6a990_row6_col1, #T_6a990_row6_col3, #T_6a990_row6_col4, #T_6a990_row6_col5, #T_6a990_row6_col8, #T_6a990_row6_col9, #T_6a990_row10_col12, #T_6a990_row12_col10, #T_6a990_row12_col11 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6a990_row0_col3 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_6a990_row0_col4, #T_6a990_row6_col2 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_6a990_row0_col5, #T_6a990_row3_col5 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_6a990_row0_col6, #T_6a990_row9_col11, #T_6a990_row11_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_6a990_row0_col8, #T_6a990_row1_col6, #T_6a990_row1_col8 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_6a990_row0_col9, #T_6a990_row1_col9, #T_6a990_row3_col8 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_6a990_row0_col10, #T_6a990_row4_col5 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_6a990_row0_col11, #T_6a990_row3_col1, #T_6a990_row7_col11 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_6a990_row0_col12 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_6a990_row1_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_6a990_row1_col2 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_6a990_row1_col3, #T_6a990_row9_col0, #T_6a990_row11_col3 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_6a990_row1_col4, #T_6a990_row7_col4, #T_6a990_row8_col7 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_6a990_row1_col5, #T_6a990_row3_col9, #T_6a990_row10_col5, #T_6a990_row11_col0 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_6a990_row1_col7, #T_6a990_row10_col11 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_6a990_row1_col10, #T_6a990_row7_col12, #T_6a990_row10_col6, #T_6a990_row11_col6 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_6a990_row1_col11 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_6a990_row1_col12, #T_6a990_row2_col9 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_6a990_row2_col0, #T_6a990_row4_col9, #T_6a990_row9_col6 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_6a990_row2_col1 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_6a990_row2_col3, #T_6a990_row8_col10 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_6a990_row2_col4, #T_6a990_row3_col7, #T_6a990_row10_col7, #T_6a990_row11_col7 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_6a990_row2_col5 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_6a990_row2_col6, #T_6a990_row7_col10 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_6a990_row2_col7, #T_6a990_row12_col1 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_6a990_row2_col8, #T_6a990_row6_col12 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_6a990_row2_col10, #T_6a990_row5_col8, #T_6a990_row5_col12 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_6a990_row2_col11, #T_6a990_row10_col4 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_6a990_row2_col12, #T_6a990_row12_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_6a990_row3_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_6a990_row3_col2, #T_6a990_row3_col11 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_6a990_row3_col10, #T_6a990_row8_col1, #T_6a990_row8_col2, #T_6a990_row9_col2 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_6a990_row3_col12 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_6a990_row4_col0 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_6a990_row4_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_6a990_row4_col2, #T_6a990_row5_col11, #T_6a990_row8_col11, #T_6a990_row12_col2, #T_6a990_row12_col7 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_6a990_row4_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_6a990_row4_col6 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_6a990_row4_col7, #T_6a990_row8_col4 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_6a990_row4_col8, #T_6a990_row6_col11, #T_6a990_row10_col2 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_6a990_row4_col10 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_6a990_row4_col11 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_6a990_row4_col12, #T_6a990_row7_col3, #T_6a990_row7_col6, #T_6a990_row8_col0 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_6a990_row5_col0, #T_6a990_row6_col10 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_6a990_row5_col1, #T_6a990_row7_col9, #T_6a990_row8_col6, #T_6a990_row10_col9 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_6a990_row5_col2, #T_6a990_row11_col8 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_6a990_row5_col3, #T_6a990_row9_col3 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_6a990_row5_col4 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_6a990_row5_col6 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_6a990_row5_col9, #T_6a990_row8_col5, #T_6a990_row9_col12 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_6a990_row5_col10, #T_6a990_row8_col12 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_6a990_row6_col7, #T_6a990_row9_col4 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_6a990_row7_col0, #T_6a990_row12_col5 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_6a990_row7_col1, #T_6a990_row7_col8, #T_6a990_row10_col1 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_6a990_row7_col2 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_6a990_row7_col5, #T_6a990_row10_col0, #T_6a990_row11_col5 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_6a990_row8_col3 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_6a990_row8_col9 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_6a990_row9_col1, #T_6a990_row10_col8 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_6a990_row9_col5, #T_6a990_row12_col3 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_6a990_row9_col7 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_6a990_row9_col8 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_6a990_row9_col10 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_6a990_row10_col3 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_6a990_row11_col1, #T_6a990_row11_col9 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_6a990_row11_col10 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_6a990_row11_col12 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_6a990_row12_col4 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_6a990_row12_col6 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_6a990_row12_col8 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_6a990_row12_col9 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6a990">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a990_level0_col0" class="col_heading level0 col0" >Application order</th>
#       <th id="T_6a990_level0_col1" class="col_heading level0 col1" >Previous qualification (grade)</th>
#       <th id="T_6a990_level0_col2" class="col_heading level0 col2" >Admission grade</th>
#       <th id="T_6a990_level0_col3" class="col_heading level0 col3" >Displaced</th>
#       <th id="T_6a990_level0_col4" class="col_heading level0 col4" >Educational special needs</th>
#       <th id="T_6a990_level0_col5" class="col_heading level0 col5" >Scholarship holder</th>
#       <th id="T_6a990_level0_col6" class="col_heading level0 col6" >Age at enrollment</th>
#       <th id="T_6a990_level0_col7" class="col_heading level0 col7" >Internat

# %% [markdown]
# Из данной матрицы можем заметить, что балл при поступлении (Admission grade) довольно сильно зависит от среднего балла предыдущего образования (Previous qualification (grade)).
#
# #### Информация о категориальных признаках в нашей задаче:

# %%
X.describe(include=['category'])
# Out:
#         Marital Status  Application mode  Course  Daytime/evening attendance  \
# count             4424              4424    4424                        4424
# unique               6                18      17                           2
# top                  1                 1    9500                           1
# freq              3919              1708     766                        3941
#
#         Previous qualification  Nacionality  Mother's qualification  \
# count                     4424         4424                    4424
# unique                      17           21                      29
# top                          1            1                       1
# freq                      3717         4314                    1069
#
#         Father's qualification  Mother's occupation  Father's occupation  \
# count                     4424                 4424                 4424
# unique                      34                   32                   46
# top                         37                    9                    9
# freq                      1209                 1577                 1010
#
#         Gender    Target
# count     4424      4424
# unique       2         3
# top          0  Graduate
# freq      2868      2209

# %% [markdown]
# Более всего одиноких студентов (1).
# Большинство студентов – дневной (1) формы обучения.
# Большинство студентов являются ранее получившими лишь среднее образование (1).
# Большинство студентов – португальцы (1).
# Матери большинства студентов имеют лишь среднее образование (12 лет обучения), а отцы большинства студентов имеют и вовсе лишь оконченный 1-й цикл базового образования (4-5 лет).
# Матери и отцы большинства студентов – неквалифицированные рабочие (9).
# Большинство студентов – женского пола (0).
# Примерно половина студентов – успешно окончившие обучение и получившие диплом.

# %% [markdown]
# # 2. Визуализация данных
# Рассмотрим сначала зависимость предсказываемого признака от балла при поступлении

# %%
X.plot(kind='scatter', x='Admission grade', y='Target')
pass

# %%
pd.plotting.scatter_matrix(X, figsize = (26, 26))
pass
